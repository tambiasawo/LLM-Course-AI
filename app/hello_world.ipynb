# %%
import pandas as pd

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(0) 

values=np.random.randn(10)
print(values)
s=pd.Series(values)
print(s)
s.plot(kind='hist', title='Histogram of Random Values')
plt.show()
# Out:
# [ 1.76405235  0.40015721  0.97873798  2.2408932   1.86755799 -0.97727788
#   0.95008842 -0.15135721 -0.10321885  0.4105985 ]
# 0    1.764052
# 1    0.400157
# 2    0.978738
# 3    2.240893
# 4    1.867558
# 5   -0.977278
# 6    0.950088
# 7   -0.151357
# 8   -0.103219
# 9    0.410599
# dtype: float64
